# %% [markdown]
# # Natural Language Processing with Disaster Tweets
#
# https://www.kaggle.com/c/nlp-getting-started/data

# %%
import os
import pandas as pd
import numpy as np
from sklearn import metrics
import re
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')
stemmer = PorterStemmer()
lemmer = WordNetLemmatizer()

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import cross_validate
from sklearn.naive_bayes import BernoulliNB

from sklearn.model_selection import train_test_split
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ruthashford/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ruthashford/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Read in data
data_fp = os.path.join(os.getcwd(), "data")
train_fp = os.path.join(data_fp, "train.csv")
train = pd.read_csv(train_fp, encoding="utf-8")
test_fp = os.path.join(data_fp, "test.csv")
test = pd.read_csv(test_fp, encoding="utf-8")

print(f"Train: {train.shape}")
print(f"Test:  {test.shape}")

train.head()
# Out:
# Train: (7613, 5)
# Test:  (3263, 4)
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# - average number of words in disaster vs non-disaster
# - average length of tweet
# - average number of disaster vs non disaster per key word
# - missing values

# %% [markdown]
# Firstly we will check the number of samples that are labelled as disaster (1) and non-disaster (0)

# %%
train_label_summary = train.groupby('target').agg(Total = ('id','count'))
train_label_summary['Percentage'] = round(train_label_summary['Total'] / train.shape[0] * 100, 1)
train_label_summary
# Out:
#         Total  Percentage
# target
# 0        4342        57.0
# 1        3271        43.0

# %% [markdown]
# This shows us that we have a fairly even split of disaster and non-disaster labelled samples. This is useful when training our model but tell us that this data set is not likely to be representative of the general population of tweets, we know in general there are far less than 43% of tweets that are about disasters.

# %% [markdown]
# ### Keywords
# Next we want to take a look at the keywords and how they relate to the target

# %%
keyword_label_summary = train.groupby('keyword').agg(percentage_disaster_occurance = ('target', 'mean')).reset_index()

keyword_disaster_count = train[train['target'] == 1].groupby('keyword').agg(disaster_count = ('target', 'count')).reset_index()
keyword_not_disaster_count = train[train['target'] == 0].groupby('keyword').agg(not_disaster_count = ('target', 'count')).reset_index()

keyword_label_summary = keyword_label_summary.merge(keyword_disaster_count, how='left')
keyword_label_summary = keyword_label_summary.merge(keyword_not_disaster_count, how='left')

# %% [markdown]
# Below are the words that come up most often in disaster tweets.

# %%
keyword_label_summary.sort_values('percentage_disaster_occurance', ascending=False).head(20)
# Out:
#                    keyword  percentage_disaster_occurance  disaster_count  \
# 62                  debris                       1.000000            37.0
# 219               wreckage                       1.000000            39.0
# 70              derailment                       1.000000            39.0
# 153               outbreak                       0.975000            39.0
# 152            oil%20spill                       0.973684            37.0
# 205                typhoon                       0.973684            37.0
# 187      suicide%20bombing                       0.969697            32.0
# 186       suicide%20bomber                       0.967742            30.0
# 32                 bombing                       0.931034            27.0
# 166               rescuers                       0.914286            32.0
# 185         suicide%20bomb                       0.914286            32.0
# 147     nuclear%20disaster                       0.911765            31.0
# 96               evacuated                       0.888889            32.0
# 162                  razed                       0.885714            31.0
# 214               wildfire                       0.878788            29.0
# 213           wild%20fires                       0.870968            27.0
# 3      airplane%20accident                       0.857143            30.0
# 139          mass%20murder                       0.848485            28.0
# 35   buildings%20on%20fire                       0.848485            28.0
# 116         forest%20fires                       0.843750            27.0
#
#      not_disaster_count
# 62                  NaN
# 219                 NaN
# 70                  NaN
# 153                 1.0
# 152                 1.0
# 205                 1.0
# 187                 1.0
# 186                 1.0
# 32                  2.0
# 166                 3.0
# 185                 3.0
# 147                 3.0
# 96                  4.0
# 162                 4.0
# 214                 4.0
# 213                 4.0
# 3                   5.0
# 139                 5.0
# 35                  5.0
# 116                 5.0

# %% [markdown]
# Below are the kewords that come up most often in non-disaster tweets. I can see that 'body%20bags' and body%20bag' is a duplicate and needs cleaning up. There are a lot of words here that I would associate with disasters, such as 'ruin', 'explode' and 'wrecked' but these are also words that could be used in a sentence when not describing a disaster.

# %%
keyword_label_summary.sort_values('percentage_disaster_occurance', ascending=True).head(20)
# Out:
#          keyword  percentage_disaster_occurance  disaster_count  \
# 2     aftershock                       0.000000             NaN
# 29   body%20bags                       0.024390             1.0
# 170         ruin                       0.027027             1.0
# 19       blazing                       0.029412             1.0
# 27    body%20bag                       0.030303             1.0
# 88   electrocute                       0.031250             1.0
# 173    screaming                       0.055556             2.0
# 201  traumatised                       0.057143             2.0
# 156    panicking                       0.060606             2.0
# 21     blew%20up                       0.060606             2.0
# 22        blight                       0.062500             2.0
# 220      wrecked                       0.076923             3.0
# 98       explode                       0.078947             3.0
# 155        panic                       0.081081             3.0
# 94     epicentre                       0.083333             1.0
# 25        bloody                       0.085714             3.0
# 180        smoke                       0.088235             3.0
# 48       collide                       0.088235             3.0
# 183    stretcher                       0.090909             3.0
# 83         drown                       0.093750             3.0
#
#      not_disaster_count
# 2                  34.0
# 29                 40.0
# 170                36.0
# 19                 33.0
# 27                 32.0
# 88                 31.0
# 173                34.0
# 201                33.0
# 156                31.0
# 21                 31.0
# 22                 30.0
# 220                36.0
# 98                 35.0
# 155                34.0
# 94                 11.0
# 25                 32.0
# 180                31.0
# 48                 31.0
# 183                30.0
# 83                 29.0

# %%
print(f' Percentage of tweets without a keyword: {round(1 - train.keyword.isna().sum() / train.shape[0] * 100 , 2)}%')
# Out:
#  Percentage of tweets without a keyword: 0.2%

# %% [markdown]
# ### Length of tweets

# %%
fig, axs = plt.subplots(2)
fig. tight_layout(pad=3.0)

disaster_length = train[train['target'] == 1]['text'].apply(lambda x: len(x))
non_disaster_length = train[train['target'] == 0]['text'].apply(lambda x: len(x))

axs[0].hist(x = disaster_length, color='red', bins=20, range = (0,160))
axs[0].set_title('Length distribution of disaster tweets')
axs[1].hist(x = non_disaster_length, bins=20, range = (0,160))
axs[1].set_title('Length distribution of non-disaster tweets')
axs[1].set_xlabel('Tweet length')

plt.show()

# %%
print(f'Average length of disaster tweets is {round(disaster_length.mean())} ' \
 f'with standard deviation {round(disaster_length.std())}')

print(f'Average length of non-disaster tweets is {round(non_disaster_length.mean())} ' \
 f'with standard deviation {round(non_disaster_length.std())}')
# Out:
# Average length of disaster tweets is 108 with standard deviation 29
# Average length of non-disaster tweets is 96 with standard deviation 36

# %% [markdown]
# ### Number of words

# %%
fig, axs = plt.subplots(2)
fig. tight_layout(pad=3.0)

disaster_wc = train[train['target'] == 1]['text'].apply(lambda x: len(word_tokenize(x)))
non_disaster_wc = train[train['target'] == 0]['text'].apply(lambda x: len(word_tokenize(x)))

axs[0].hist(x = disaster_wc, color='red', bins=20, range = (0,40))
axs[0].set_title('Word count distribution of disaster tweets')
axs[1].hist(x = non_disaster_wc, bins=20, range = (0,40))
axs[1].set_title('Word count distribution of non-disaster tweets')
axs[1].set_xlabel('Tweet word count')

plt.show()

# %% [markdown]
# ## Baseline model
#
# ### Split data into train and development
# We will reserve 20% of the training data to be used as development data to test iterations of the model against.

# %%
# Split into train an development data sets
train_data, dev_data, train_labels, dev_labels = train_test_split(train["text"], \
                                                                  train["target"],\
                                                                  test_size = 0.2, \
                                                                  random_state =24)
print(f'Train data set contains {train_data.shape[0]} samples')
print(f'Development data set contains {dev_data.shape[0]} samples')
# Out:
# Train data set contains 6090 samples
# Development data set contains 1523 samples

# %% [markdown]
# ### Bernoulli Naive Bayes
# Starting off with a bernoulli naive bayes model, using the default parameters.
# Using a simple count vectorizer to create a feature space for the model based on the occurance of a word.

# %%
cv = CountVectorizer()
cv.fit(train_data)
train_vec = cv.transform(train_data)
dev_vec = cv.transform(dev_data)

model = BernoulliNB()
model.fit(train_vec, train_labels)
preds = model.predict(dev_vec)

print(f'F1 score is: {metrics.f1_score(dev_labels, preds, average="weighted")}')
metrics.plot_confusion_matrix(model, dev_vec, dev_labels)
# Out:
# F1 score is: 0.8141627446332516

# %% [markdown]
# Lots of false negatives here. Let's look at what is getting misclassified.

# %%
def false_negatives(preds, data):
    print('Classified as negative but are positive')
    print('---------------------------------------\n')
    df = pd.DataFrame()
    df['text'] = data
    df['labels'] = dev_labels
    df['predictions'] = preds
    for tweet in df[(df.labels == 1) & (df.predictions == 0)].text:
        print(tweet)

# %%
def false_positives(preds, data):
    print('Classified as positive but are negative')
    print('---------------------------------------\n')
    df = pd.DataFrame()
    df['text'] = data
    df['labels'] = dev_labels
    df['predictions'] = preds    
    for tweet in df[(df.labels == 0) & (df.predictions == 1)].text:
        print(tweet)

# %%
false_negatives(preds, dev_data)
# Out:
# Classified as negative but are positive
# ---------------------------------------
#
# Bradford. Back to doing what we do best. Burning down our own buildings. Read it and weep Leeds. https://t.co/OLnfzb86zb
# But if you build an army of 100 dogs and their leader is a lion all dogs will fight like a lion.
# I'M LAUGHING IN THE FACE OF CASUALTIES AND SORROW THE FIRST TIME I'M THINKING PAST TOMORROW BUT I AM NOT THROWIN AWAY MY SHOT
# I've experienced the smell of rotting potatoes for the first time. The Famine must have been awful if the whole country smelled like that.
# These wild fires out west are crazy.
# On the sneak America has us spoiled. A natural disaster will humble niggas.
# @APhiABeta1907 w/ugliness due 2 your 'ugly'@AMESocialAction Frat's BIOTERRORISMI'm she who's @FBI ID U $tolewant'g another in my Home.@ABC
# @MichaelWestBiz standard damage control
# @fewmoretweets all lives matter. Just not a fan of burning down buildings and stealing from your neighbors to 'protest'
# Blue Bell May Be Close to a Return From Its Listeria Disaster... Hot on #theneeds #Recipes http://t.co/F56v61AmPt
# @pattonoswalt @FoxNews Wait I thought Fecal Hurricane was on SciFi? Maybe that was turdnado. I've been forgeting up a shit storm lately.
# Watch These Super Strong Magnets Destroy Everyday Objects: http://t.co/bTUs5jejuy http://t.co/zrTfxLuk6R
# This fire is WAY too close wtf is going on ???? http://t.co/drf3mmRbyx
# Even if u have your weapon and your badge we gonna put them choppas on your ass????
# Short of throwing them overboard himself I don't think any other leader could do much worse by #refugees than @TonyAbbottMHR worst pm ever!
# Someone teaching you that obedience will obliterate trials in your life is trying to sell you a used car. Jesus's life blows that theory.'
# @NigelTanner1 Believe it or not we've had too MUCH rain here. Our newly planted maple trees are actually drowning.
# The ol' meltdown victory for the Mets.
# #PBBan (Temporary:300) hyider_ghost2 @'aRmageddon | DO NOT KILL | FLAGS ONLY | Fast XP' for Reason
# @dreamoforgonon @TeeEss not to hijack but as a bona fide cislady I can confirm this as true; incidental homosexuality =/= gay/bi for women.
# @kiranahmedd US military and Nato are fighting Talibans too
# Check out my Lava lamp dude ???? http://t.co/To9ViqooFv
# World War II book LIGHTNING JOE An Autobiography by General J. Lawton Collins http://t.co/R4khEH7iaf http://t.co/qSZgJfUutu
# @HighQualityBird a reverse situation (lol I don't know 9/11?) where US civilian deaths were specifically utilized to make a political
# Rainstorm downtown Gloucester
# #gloucester #capeann #seagulls #triciaoneill #triciaoneillphoto https://t.co/oLS6qdi9Um
# I feel like if MKayla and Cee ever got in the same room everyone should evacuate because it would be so petty and childish I couldn't deal
# @115Film Doctor we must leave immediately the Core is unstable...The whole building is told to be evacuated. Take the research. We need...
# A Pyrotechnic Artwork by Cai Guo-Qiang Explodes into a Blossom on the Steps of the Philadelphia... http://t.co/orOvZFsKU2
# Damn that sinkhole on sunset????
# I know it's a question of interpretation but this is a sign of the apocalypse.  I called it https://t.co/my8q1uWIjn
# @SaintRobinho86 someone has to be at the bottom of every league. Tonight clearly demonstrated why the Lions are where they are - sunk!
# 4 equipment ego break upon dig your family internet hoke excepting versus a sinking term: dfLJEV
# Offers : http://t.co/Gl3C1vc88P #8392 Deluxe Toilet Safety Support/Health/Home/Bathroom/Support/Elderly/Injured/SÛ_ http://t.co/vihdoKScCC
# In the words of Charlie Daniels 'Fire on the mountain run boys run.'Û_ https://t.co/fz1HAEj255
# @Gurmeetramrahim #MSGDoing111WelfareWorks Green S welfare force ke appx 65000 members har time disaster victim ki help ke liye tyar hai....
# Wreck with road blockage Woodward Avenue Northbound at Davison in M.S. #shoalstraffic
# U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/sW1sBua3mN via @Change
# @DavidVitter Hi David in 2003 I saw the USA walk into a war that destroyed the lives of millions. You can prevent a repeat. #IranDeal
# Tomorrow's evening commute receives a RED LIGHT. A rainstorm impacting the region will push it's way in late evening. http://t.co/DRvm8ISOtE
# 'It looks like a mudslide!' And #GBBO is back with a belter!
# Calgary pounded with hail on second day of storms https://t.co/2BE7BwcMpl
# Well so much for outdoor postering @calgaryfringe #mothernature #hailstorm #rain #yycfringe #KILLHARD
# I'll be at SFA very soon....#Pandemonium http://t.co/RW8b50xz9m
# @eyecuts @Erasuterism I love 96 Gal Deco to death even if it's a bit trickier to be great with. Glad more weapons are getting Splash Wall
# Byproduct of metal price meltdown is a higher silver price http://t.co/cZWjw4UV7i
# #Biztip We recommend all businesses to get an alternative source of electricity. #Solar Wind and Batteries. Have an emergency plan! Now!
# Well that was a journey to get home! A train collided with cows on the track! ????
# Destruction magic's fine just don't go burning down any buildings.
# Buildings are on fire and they have time for a business meeting #TheStrain
# @robbiewilliams U fkn asswipe playing for Israeli child killers.. The fkn karma police will get U.
# @zaynmaIikist listen to hurricane
# DC Media: tip for getting updates on the derailed #WMATA train today - ask them about movie night and quickly change the subject!
# Good way to end the day!!! Geyser plus dust storm! http://t.co/l5VakLR59M
# Love living on my own. I can blaze inside my apt or on the balcony
# Now that's what you call a batting collapse #theashes
# The Seven Seas - Wreck of the Giannis D. sunk after hitting a submerged reef in theÛ_ http://t.co/Gn3WHNSFIb http://t.co/fWpOF5TwoC
# If I'm also not mistaken we're sitting right next 2 a nuclear reactor. Not smart when we have a cataclysmic event &amp; that reator melts down.
# It's a miracle that mankind survived 70 years since one of the worst days in its history. All bets are off if it will survive the next 70.
# Some people are really natural disaster too
# Must get hot in burning buildings
#
# -loses followers- https://t.co/8sP8xLbbDR
# @modnao23 the hail is ruining everything. Plus my car I haven't even gotten yet. Have yet another killer migraine and I lost my glasses. ??
# Until my death I'll forever rep the Jets.
# it scares me that there's new versions of nuclear attack warnings like just knowing that governments still prepare for them
# @PianoHands You don't know because you don't smoke. The way to make taxis and buses come is to light a cigarette to smoke while you wait.
# Pendleton media office said only fire on base right now is the Horno blaze.
# tianta_: Breaking news! Unconfirmed! I just heard a loud bang nearby. in what appears to be a blast of wind from my neighbour's ass.
# Smelling a Bon fire while driving makes me wanna be sitting near one making s'mores ????
# @_301DC @Cloudy_goldrush i hate white people mo
# kesabaran membuahkan hasil indah pada saat tepat! life isn't about waiting for the storm to pass it's about learning to dance in the rain.
# @marcoarment Middle of winter in Sydney we have had snow bush fires and 78 degree days in the last week.  Keeps you on your toes for sure.
# RT patrickjbutler: Excellent damiengayle eyewitness account of Kids Company closure: 'You drop the bomb and expectÛ_ http://t.co/pHH1VmLfoo
# @itss_selenaluna like a beautiful ass tragedy lol
# @DalaiLama then have the biggest nuclear disaster to ever have happened
# Sadly the tent fly did not survive this hailstorm and now I have tears in the roof and water in the tent.  Only... http://t.co/zCt5cchOJ0
# @Michael5SOS haha so would you say its so hot your balls are burning off????
# Does anyone know why #murfreesboro #walmart was evacuated this evening? @dnj_com
# #hot  Funtenna: hijacking computers to send data as sound waves [Black Hat 2015] http://t.co/UMgD92wLjA #prebreak #best
# Hellfire is surrounded by desires so be careful and donÛªt let your desires control you! #Afterlife
# Hollywood Movie About Trapped Miners Released in Chile: 'The 33' Hollywood movie about trapped miners starring... http://t.co/tyyfG4qQvM
# @AisuMage @AkumaReisu --just between Gray and Ophelia red flames blazing around her person setting nearly everything in the area--
# Kirsten Gillibrand http://t.co/amEA3LaMDj    Extend Health Care To 911 First RESPONDERS !
# Ready to get annihilated for the BUCS game
# @USAgov Koreans are performing hijacking of the Tokyo Olympic Games.https://t.co/APkSnpLXZj
# Myanmar floods: Childfund https://t.co/pQHQ4JnZTT
#  and International Needs https://t.co/FX0W2Sq05F and CARE Aust @CAREemergencies appeals
# @Sweet2Young -runs at her for setting my forest on fire and bites the shit out of her neck-
# @Michael5SOS California is in a drought. what are you gonna do about this issue? if you want to be president this attitude won't work with m
# Heat wave is relentless:  91å¡F Feels Like 100 Humidity 55% +
# relentless drought too: now Dominicana. I know is worse in other places.
# @CalFreedomMom @steph93065 not to mention a major contributor to the annihilation of Israel
# Mmmmmm I'm burning.... I'm burning buildings I'm building.... Oooooohhhh oooh ooh...
# I will adamantly opposed to nuclear weapons.
# @Vickie627 Desert Storm was an unqualified victory a treaty was signed.  Under Clinton the situation only got worse and more violent. #tcot
# Escaping her captors was the 1st step. Now she must survive a deadly storm &amp; a wild-looking recluse.
# BETRAYED
# http://t.co/0Q040STkCV
# #books
# @PhilipDuncan @breakfastone People 'annihilated by last nights weather'... Really Philip thought you would have forecast that...
# Could Billboard's Hot 100 chart be displaced by these social-media-driven music charts?    http://t.co/WVlaH8jRXe
# Nothing like a good fire https://t.co/ItFbBz9xYC
# Reminder: Mass murderer and white supremacist Anders Breivik was also unsurprisingly an anti-feminist.
# http://t.co/1lXnJVl8TR
# Worried about how the CA drought might affect you? Extreme Weather: Does it Dampen Our Economy? http://t.co/fDzzuMyW8i
# Still rioting in a couple of hours left until I have to be up for class.
# GREAT MICHIGAN TECHNIQUE CAMP
# B1G THANKS TO @bmurph1019
# @hail_Youtsey . @termn8r13
# #GoBlue #WrestleOn http://t.co/OasKgki6Qj
# @YoungHeroesID Lava Blast dan Power Red #PantherAttack @CunayyH @TaufikCJ
# AM `bbcnews The Ass British Insurers says rioting will cost insurers163;millions. But police numbers are reduced by blind fat controllers.
# @YoungHeroesID LAVA BLAST dan POWER RED #PantherAttack @Mirmanda11 @evaaaSR
# Weather forecast for Thailand  A Whirlwind is coming ...2 september https://t.co/rUKjYjG9oQ
# @selmoooooo @_edvinnn @imTariik @dzafic_haris selmo u not catching flames from me  im just gonna be witnessing the slaughter
# A better look at what this catastrophic rain and flooding has done to ourÛ_ https://t.co/5yRBegzafX
# 'It looks like a mudslide' poor thing! ?? #greatbritishbakeoff
# U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... http://t.co/SB5R7ShcCJ via @Change
# I see a massacre!!
# #360WiseNews : China's Stock Market Crash: Are There Gems In The Rubble? http://t.co/9Naw3QOQOL
# Pizza and beer in a tornado in Austin. Windy af right now
# Storm in RI worse than last hurricane. My city&amp;3others hardest hit. My yard looks like it was bombed. Around 20000K still without power
# burned 129 calories doing 24 minutes of Walking 3.5 mph brisk pace #myfitnesspal
# @ThatSabineGirl you get me sis. this planet could do with a huge dose of obliteration.
# @KurtSchlichter  He's already done it by negotiating with the #1 state of terrorism in the World. What was his hurry in trying to get a deal
# Hellfire! We donÛªt even want to think about it or mention it so letÛªs not do anything that leads to it #islam!
# My baby girls car wreak this afternoon thank God no serious injuries and she was wearing her seatbelt!!!... http://t.co/NJQV45ndS2
# @BrittanyPetko breaking news tonight kids were rescued from play room after a week with no food or water do to parents sex life haha
# This week first responders and DART members are participating in a four day intensive Technical Large Animal... http://t.co/tL93AOd3ER
# ok peace I hope I fall off a cliff along with my dignity
# 2pcs 18W CREE Led Work Light  Offroad Lamp Car Truck Boat Mining 4WD FLOOD BEAM - Full reaÛ_ http://t.co/ApWXS5Mm44 http://t.co/DS76loZLSu
# We have overrun a Natural Disaster Survival server!
# @AFK_10 @Dr_JohanFranzen ISIS are orchs. But they don't have the ability to massacre civilians far from the frontlines like the tyrant.
# @LEDofficial1 As you can imagine we're inundated with requests each week for samples &amp; as much as we'd love to be able to send sweets 1/2
# @Cali74142290 lol natural disaster/hospital crisis something is needed to get rid of some cast members....
# A new tropical cyclone is forming near Guam.
#
# Once it is formed it will be called 'Molave'.
# I WAS PEACEFULLY SITTING IN MY ROOM AND I HEARD THIS LOUD BANG OF SOMETHING FALLING
# I just wanted to watch Paper Towns but the buildings on fire ?????
# For these Californians it's like living in Africa's Sahel desert - just finding water a daily chore. http://t.co/ySG9vsrT4g
# Stop the Annihilation of the Salt River Wild Horses! http://t.co/wVobVVtXKg via @Change
# sevenfigz has a crush: http://t.co/20B3PnQxMD
# @_jeesss_ @Ethereal_7 Hello 911 yeah we have someone drowning here send a medic http://t.co/7GiglwdMhy
# someone: mentions gansey on fire
# me busting through the brick walls of seven different buildings:
# @emmerdale can we have a public vote for the next annual village disaster?  i want an isis strike or a nuclear accident &amp; end this forever
# *books a flight to Burma when country is enduring political unrest and a natural disaster* no wonder it was so cheap ay
# Zeal is a volcano the peak of which the grass of indecisiveness does not grow
# Benzema increasingly looks to be a casualty of Benitez's new look squad. Arsenal bound? 50-50 chance I think
# @lavapixcom Did you see #hurricane #guillermo with #MeteoEarth? http://t.co/mfckpVzfV8
# Back on the beach after the deluge.  Surf camp in motion.  Our Surf Therapy programme kicked off today for... http://t.co/vjsAqPxngN
# @rjkrraj @KarnakaranK @vimvith whether pressure or not NON wud not survived even if thalapathi didn't release
# I hope this tsunami clears b4 i have to walk outside to my car ????
# #gunsense answer to #GFZ's: break law on the minuscule chance a mass murderer shows up. https://t.co/qEoPMCJbCz
# Ancient Mayan Tablet Found in Jungle Temple http://t.co/qp6q8RS8ON
# @AlfaPedia It might have come out ONLY too burst as a Bomb making him suicide bomber
# Hollywood Movie About Trapped Miners Released in Chile http://t.co/qkrLtrd39B
# Tennessee lesbian couple faked hate crime and destroyed own home with arsonÛ_ http://t.co/10mUEY8PXJ #Lesbian
# Hurricane 30STM quem lembra
# The second part which focuses on the survivors is really difficult to watch but at the same time is really powerful.
# Inbounds/ Out of Bounds:
#
# While many picked the Nats to win the NL East in a landslide they currently sit 2... http://t.co/l0dEoCxU6o
# Good thing there was actually just a legit fire in the mall and nobody evacuated!!
# @HaydnExists so glad i saved them all at once then didnÛªt want you stealing my thunder :P
# OMFG??
# Didnt expect Drag Me Down to be the first song Pandora played
#
# OMFG I SCREAMED SO LOUD
# My coworker is scared http://t.co/VzcvAdkcQp
# Freak #Boston #hailstorm produces a hailstorm of business ... for auto-body repair specialists. @PeterHoweNECN 6:30/8:30 TONIGHT @necn
# @sonofbobBOB @Shimmyfab @trickxie usually I'd agree. Once the whole chopping heads off throwing gays off rooftops &amp; suicide bombing start
# Not only does he know the latest research the kiddo's GI specialist sang the volcano number from Inside Out. Now THAT is whole person care.
# @cspan #Prez. Mr. President you are the biggest terrorist and trouble maker in the world. You create terrorist you sponsor terrorist.
# .Sink Holes Earth Slides And Avalanches&gt;&gt;https://t.co/XrRLnheLaP
# #Allah #Islam #sinkhole #landslide #avalanche #USA #France #UK #usgs #emsc
# Sustainability Task Force Presents Levy to Fund Emergency Services - WDTV http://t.co/2FiBE2HAXC
# UD: Rescue (Structural Collapse) - Scott Road @ Ypres Road York (14 Trucks)
# @HeyImBeeYT its like theres fire in my skin and im drowning from within ????
# Only you can prevent forest fires. ???? http://t.co/rGYUaKc0dR
# The thunder shook my house woke my sister and made car alarms go off ????
# I'm on top of the hill and I can see a fire in the woods...
# A big issue left undone is HOW to get home if adverse weather hits. @GoTriangle has no real emergency plan in place https://t.co/s7xdXuudcy
# WIN: Lisowski whitewashes the Whirlwind 5-0 in round 2 of Shanghai Masters Quals! |  http://t.co/MLigPUHVOh #snooker http://t.co/TcS2Cd5y6y
# Body shops inundated with cars dented by hail... Good news insurance pays... Bad news :  you are stuck with deductible !
# #wcvb
# If you're in search of powerful content to improve your business or have been frustrated with the deluge of 'quantitÛ_https://t.co/64cyMG1lTG
# I just added 'Sandy First Responders Lost Their Homes' to VIP Home Page Group on @Vimeo: https://t.co/lKXi6UXjaQ
# We're #hiring! Click to apply: RN II/EMERGENCY SERVICES/FT/7P-7A - http://t.co/NV3Uxv9IMX #Nursing #Houston TX http://t.co/ej30IhrEA9
# @PrablematicLA @Adweek I'm actually currently dressed for a snowstorm...despite being in the middle of a Texas summer. Thanks office A/C.
# @casewrites when it rains in NJ it flash floods. Otherwise its just a desert of grief and taxes.
# UD: Rescue (Structural Collapse) - Scott Road @ Ypres Road York (14 Trucks)
# Now on WSLS: fire burns multiple buildings in #Montgomery Co tips to make childcare less expensive &amp; rain. Join @jennasjems @PatrickWSLS
# @RobertHarding @RepJohnKatko Crazy to use the Netanyahu argument Iran can flush A NUCLEAR REACTOR DOWN THE TOILET
# *looks outside at the windstorm* niiiice
# Came across this fire video not mine..enjoy..#fire #firemen #firetruck #emergency #rescue #911 #summertime #sirensÛ_ http://t.co/hcYAJsAcfJ
# So much shit has happened today wtf idk how I survive thruuu it all
# Julian Knight - @SCVSupremeCourt dismisses mass murderer's attempt to increase prisoner pay. Challenged quantum of 5% increase 2013.
# My hand is burning
# http://t.co/rOdpt33XFM EverSafe Emergency Auto Kit for all Weather Unsafe hazardous rush-hour gridlock jumper-caÛ_ http://t.co/0BVK5tuB4J
# @ColdMpress You up to commiting mass murder tonight?
# New post from @darkreading http://t.co/8eIJDXApnp New SMB Relay Attack Steals User Credentials Over Internet
# Why weren't they taken back to Africa once rescued? #c4news
# #NowPlaying: Dubstep Hardstyle Trap Messy Mix (event recording) by Alien Casualty on @Mixify http://t.co/m203UL6o7p http://t.co/m203UL6o7p
# @ameenshaikh3 by ur. logic if bridge didnt collapse then second train engine should cross bridge then  @sanjaynirupam @sureshprabhu
# ÛÏ@LordBrathwaite: Everyone Here: Ahh I hate snow!
#
# Me: Lol u call this a snowstorm..?
#
# #growingupincoloradoÛ
# (SJ GIST): 148 Houses Farm Produce Destroy... http://t.co/dkrGS2AWEX #StreetjamzDotNet | https://t.co/mR9KcGpIwM
# Exploring New Worlds: Three Moments of an Explosion by China MiÌ©ville http://t.co/OTrwZ1t9sp http://t.co/xVlkFCvfX5
# Thunder lightening torrential rain and a power cut!
# I liked a @YouTube video http://t.co/bGAJ2oAX1p Huge Building Explosion at 2500fps - The Slow Mo Guys
# Keeps askin me what this means
# Not like i got the answers
# Plus if i say the wrong thing
# This might just turn into a disaster
# The sunset looked like an erupting volcano .... My initial thought was the Pixar short Lava http://t.co/g4sChqFEsT
# @noah_anyname The utopian impulse inevitably ends in gulags and mass murder.
# earthquake drill atm
# Wild land fires.. Here I come. ??????
# Leeds fan.... rioting in Embra at a lower tier/ league cup final ... dee dum
# WIPP emergency activated because of slightly elevated levels of radiation. #sejorg
# @MartynWaites It's a well-known fact that the St Valentine's Day massacre could have been avoided with some 'oompah-period' Tom Waits.
# You picture buildings burning to the ground from the basement to the streetlight.
#
# I'm not your drinking problem
# a hole is in the sky.
# 'I came to kill Indians...for FUN': Video of smirking and remorseless Pakistani killer shows him boasting. http://t.co/FPjLwOXKlg
# @blakeshelton DON'T be a FART ??in a WINDSTORM.FOLLOW ME ALREADY. JEEZ.
# @hollywarnexx mini heat wave apaz
# Let's not forget our wounded female veterans. http://t.co/rZ7fbr10xw
# 'Some hearths they burn like a wildfire' https://t.co/of3td6DGLb by Bees Knees
# Interview on The Collapse of Materialism Best #TalkRadio Listen Live: http://t.co/sDXZHjco0X
# Is he about to crash?
# Did the Queen die?
# Did something explode?
# Who knows. http://t.co/LThMwtl5fP
# Deliver Value: A Cash Source Crash Course http://t.co/st5fGBLsYe #course http://t.co/0uK0H9hOzn
# The president spoke of Kennedy's diplomacy to avert nuclear disaster during the Cold War to bolster his own pitch for Congress' approval
# the_af comments on 'New evidence of Japan's effort to build atom bomb at the end of WWII' - http://t.co/hcTxghR2Yf
# I learned more about economics from one South Dakota dust storm than I did in all my years in college.  -Hubert Humphrey
# Okay not sure the word 'mass murder' applies during this war but it was horrendous none the less. https://t.co/Sb3rjQqzIX
# the sunset boys wreck my bed   original 1979 usa gimp label  vinyl 7' 45  newave http://t.co/X0QLgwoyMT http://t.co/hQNx8qMeG3
# Pandemonium use to be my fav cd ?? I had to get it http://t.co/6WhUgaeM3C

# %% [markdown]
# Lots of these have hyperlinks and @ symbols as well as other special charaters. We can do some preprocessing of the text to help.

# %% [markdown]
# Things to try
# 1. remove hashtags
# 3. remove urls

# %%
def stem_sentence(text):
    token_words=word_tokenize(text)
    stem_sentence=[]
    for word in token_words:
        stem_sentence.append(stemmer.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)

def lem_sentence(text):
    token_words=word_tokenize(text)
    stem_sentence=[]
    for word in token_words:
        stem_sentence.append(lemmer.lemmatize(word, pos='n'))
        stem_sentence.append(" ")
    return "".join(stem_sentence)

def clean_text(text):
    text = text.lower()
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    text = re.sub(r'http?:\/\/.*[\r\n]*', '', text)
    text = re.sub(r"(?:\@)\w+", ' ', text)
    text = re.sub(r'[:"#$%&\*+,-/:;<=>@\\^_`{|}~?!]+',' ',text)
    text = re.sub(r"[']+",'',text)
    # try subbing 911 or 999 first then dealing with numbers
    #text = re.sub(r'[0-9]+', 'num', text)
    
    text=text.replace(r'&amp;?',r'and')
    text=text.replace(r'&lt;',r'<')
    text=text.replace(r'&gt;',r'>')
    
    text=text.encode("ascii",errors="ignore").decode()

    return text

def clean_and_lem(text):
    return lem_sentence(clean_text(text))

def clean_and_stem(text):
    return stem_sentence(clean_text(text))

# %% [markdown]
# ### Clean tweets text

# %%
cv = CountVectorizer(analyzer='word', preprocessor=clean_text)
cv.fit(train_data)
train_vec = cv.transform(train_data)
dev_vec = cv.transform(dev_data)

model = BernoulliNB(alpha=0.8)
model.fit(train_vec, train_labels)
preds = model.predict(dev_vec)

print(f'F1 score is: {metrics.f1_score(dev_labels, preds, average="weighted")}')
metrics.plot_confusion_matrix(model, dev_vec, dev_labels)
print(metrics.classification_report(dev_labels, preds))
# Out:
# F1 score is: 0.81920517904817
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86       875
#            1       0.86      0.70      0.77       648
#
#     accuracy                           0.82      1523
#    macro avg       0.83      0.81      0.81      1523
# weighted avg       0.83      0.82      0.82      1523

# %% [markdown]
# The recall of the postive samples is pretty low, we need to get that up to see an increase in F1 score.

# %% [markdown]
# ### Stem words

# %%
cv = CountVectorizer(analyzer='word', preprocessor=clean_and_stem)
cv.fit(train_data)
train_vec = cv.transform(train_data)
dev_vec = cv.transform(dev_data)

model = BernoulliNB(alpha=0.8)
model.fit(train_vec, train_labels)
preds = model.predict(dev_vec)

print(f'F1 score is: {metrics.f1_score(dev_labels, preds, average="weighted")}')
metrics.plot_confusion_matrix(model, dev_vec, dev_labels)
print(metrics.classification_report(dev_labels, preds))
# Out:
# F1 score is: 0.8146222445666332
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85       875
#            1       0.84      0.71      0.77       648
#
#     accuracy                           0.82      1523
#    macro avg       0.82      0.80      0.81      1523
# weighted avg       0.82      0.82      0.81      1523

# %% [markdown]
# Stemming has made the number of false positives increase

# %% [markdown]
# ### Lemmatizing

# %%
cv = CountVectorizer(analyzer='word', preprocessor=clean_and_lem)
cv.fit(train_data)
train_vec = cv.transform(train_data)
dev_vec = cv.transform(dev_data)

model = BernoulliNB(alpha=0.8)
model.fit(train_vec, train_labels)
preds = model.predict(dev_vec)

print(f'F1 score is: {metrics.f1_score(dev_labels, preds, average="weighted")}')
metrics.plot_confusion_matrix(model, dev_vec, dev_labels)
print(metrics.classification_report(dev_labels, preds))
# Out:
# F1 score is: 0.822819811554472
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86       875
#            1       0.86      0.71      0.78       648
#
#     accuracy                           0.83      1523
#    macro avg       0.83      0.81      0.82      1523
# weighted avg       0.83      0.83      0.82      1523

# %% [markdown]
# Looking a bit better.

# %% [markdown]
# ### Term Frequency - Inverse Document Frequency

# %%
cv = TfidfVectorizer(preprocessor=clean_and_lem, encoding='utf-8',
                       ngram_range=(1,1),
                       max_features=11000, 
                       norm='l2'
                    )
cv.fit(train_data)
train_vec = cv.transform(train_data)
dev_vec = cv.transform(dev_data)
model = BernoulliNB(alpha=0.75)
model.fit(train_vec, train_labels)
preds = model.predict(dev_vec)

print(f'F1 score is: {metrics.f1_score(dev_labels, preds, average="weighted")}')
metrics.plot_confusion_matrix(model, dev_vec, dev_labels)
print(metrics.classification_report(dev_labels, preds))
# Out:
# F1 score is: 0.825008409294963
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86       875
#            1       0.86      0.71      0.78       648
#
#     accuracy                           0.83      1523
#    macro avg       0.84      0.81      0.82      1523
# weighted avg       0.83      0.83      0.83      1523

# %%
false_positives(preds, dev_data.apply(lambda x: clean_and_lem(x)))
# Out:
# Classified as positive but are negative
# ---------------------------------------
#
# exploration take seismic shift in gabon to somalia worldoil ( subscription )
# generational british schism over privacy threat of drone drone privacy
# islamic state issue a new holiday brochure lovely swimming pool for drowning in shooting range and the downside it cost a bomb
# county 911 overload prompt use of emergency plan during july 4 celebration
# our garbage truck really caught on fire lmfao
# calgary news weather and traffic for august 5 45
# falling asleep to the sound to thousand of river plate fan in the stadium and a thunderstorm vivaargentina
# angry woman openly accuses nema of stealing relief material meant for idp an angry internally displaced wom
# new york a whirlwind day of activity in new york breakfast at the millennium hotel united nation plaza lunch
# [ latest post ] bayelsa poll tension in bayelsa a patience jonathan plan to hijack apc pdp
# camping in a war zone with roving raccoon toughens city slicker
# mgn africa pin 263789f4 correction tent collapse story correction tent collapse story
# i just nearly crashed my car typing paul rudd attacked by flying ant into note on my phone
# flood fishing finally sunshine amp fab deal from albertsons anniversary sale lauren paint a beautiful life
# england east coast dogger bank westward 1 seismic survey in progress by m v western regent towing a 8400 metre long cable within area
# the government is concerned about the population explosion and the population is concerned about the government explosion joe moore
# the angel of history propelled into the future by the wind of progress leaf in it wake pile of death and destruction wb
# catastrophic fallen angel reveillertm macabrelolita i wa supposed to write amino acid and i nearly
# rspca site multiple 7 story high rise building next to low density character residential in an area that flood
# notley flattened harper in his heartland harper imported ten of thousand of tfw slave cost albertans job
# pizza drought is over i just couldnt anymore
# at least they arent burning building and looting store
# robert ballews log statement are always at the fatal level
# this govt of hubris ha small maj yet act a if it ha a landslide opposition reqd with vision rigour amp hunger to serve this democracy
# governor allows parole for california school bus hijacker fresno linked local network
# coming atcha from boston had golfball sized hail yesterday sunny amazing sky today parkchat
# what dems do blaze covered month ago chicago police detained thousand of black american at interrogation facility
# 95 03 bmw 528 530 540 740 emergency warning hazard switch button oem 20177 707d
# it more of a structural breakdown or maybe a patience failure on their part
# no idea what this mean look at our violent crime rate without weapon ban gun we become like mexico not australia
# 53 year ago this week is the anniversary of marilyn monroe death ripriprip
# oil price falling but driver could reap benefit
# doe this prepare u hhs selects 9 regional special pathogen treatment center bioterrorism infectious ebola
# rfp fire truck service body for f 450 ( fire fighting rescue amp safety equipment transporta
# drown by bring me the horizon ( at information resource centre ( utp ) )
# this attempted mass murder brought to you by the obama administration
# battlefield 4 funny moment duke of hazard undercover soldier mav t
# the storm a violent swell of emotion then nothing
# i keep sneezing either someone placed a southern dust storm in my house or someone talkin smack
# add familia to the arson squad
# is one of the challenge on tough enough rescuing people from burning building
# aug 06 2015 radio show article 1 ] eyewitness account of abortion organ harvesting by planned parenthood
# the medium need to stop publicizing mass murder so many sick people want the eye of the world and the medium
# air group is here to the rescue we have 24 7 emergency service learn more about it here
# 1970 mercury cyclone gt hood moulding very nice core cobra jet 429cj gt
# rt gunshot wound 9 is in the bicep only 1 of the 10 wound that is not in the chest torso area kerricktrial jonathanferrell
# everything ha sunk in except the fact that i am actually moving to the state of colorado tomorrow been dreaming of it since i wa a kid
# a 17 year boy scout created a mini nuclear reactor in his home
# brings her alabama thunder back to the attic september 26 ticket
# kosciusko police investigating pedestrian fatality hit by a train thursday
# devastated by today allegation
# awwww baby walter rewatchingthepilot teamscorpion cyclone
# national free root beer float day is tomorrow at a amp w from 2pm close help support the wounded warrior project with donation )
# his majesty emperor salman khan unstoppable cyclone of entertainment humanity bajrangi bhaijaan creating history everywhere crosed 300 cr
# vassalboro house to be razed to make way for public gazebo report
# calgary news weather and traffic for august 5 90
# the u s department of commerce ha been deluged the last two month with com
# shes a suicide bomb
# advice from noah dont go running in a thunderstorm
# only one commodity ha escaped the total collapse in price
# the chinese are flooding nyc market like never before
# public hearing on 2015 16 budget thurs 8 6 at 3 15 emergency service ctr goshen
# borrower concerned at possible interest rate rise this could be a catastrophe
# survivor of shanghai ghetto reunite after 70 year
# two jewish terrorist charged in historic church arson the ugly truth
# beautiful lightning a seen from plane window
# canceling deal for 2 warship france agrees to repay russia via
# i reject the law of the misguided false prophet imprison nation fueling self annihilation
# s3xleak ph0tos of 19yrs old ash lady in festac town from delta exp0sed on bbm 5 leaked picture
# haley lu richardson fight for water in the last survivor ( review )
# condition for paris fr at 4 00 am cest current condition fair 68 fforecast thu sunny high 87 low 61 fri pm thunderstorm
# completely understandable considering the trauma ptsdchat
# i pledge allegiance to the p o p e and the burning building of epic city
# newlywed feed thousand of syrian refugee instead of hosting a banquet wedding dinner
# for those displaced by disaster label and legal status remain out of reach

# %%
false_negatives(preds, dev_data.apply(lambda x: clean_text(x)))
# Out:
# Classified as negative but are positive
# ---------------------------------------
#
# bradford  back to doing what we do best  burning down our own buildings  read it and weep leeds
# but if you build an army of 100 dogs and their leader is a lion all dogs will fight like a lion
# im laughing in the face of casualties and sorrow the first time im thinking past tomorrow but i am not throwin away my shot
# ive experienced the smell of rotting potatoes for the first time  the famine must have been awful if the whole country smelled like that
# on the sneak america has us spoiled  a natural disaster will humble niggas
#   w ugliness due 2 your ugly  frats bioterrorismim she whos   id u  tolewantg another in my home
#   standard damage control
#   all lives matter  just not a fan of burning down buildings and stealing from your neighbors to protest
# blue bell may be close to a return from its listeria disaster  hot on  theneeds  recipes
#     wait i thought fecal hurricane was on scifi  maybe that was turdnado  ive been forgeting up a shit storm lately
# watch these super strong magnets destroy everyday objects
# this fire is way too close wtf is going on
# even if u have your weapon and your badge we gonna put them choppas on your ass
# short of throwing them overboard himself i dont think any other leader could do much worse by  refugees than   worst pm ever
# someone teaching you that obedience will obliterate trials in your life is trying to sell you a used car  jesuss life blows that theory
#   believe it or not weve had too much rain here  our newly planted maple trees are actually drowning
# the ol meltdown victory for the mets
#  pbban (temporary 300) hyider ghost2  armageddon   do not kill   flags only   fast xp for reason
#     not to hijack but as a bona fide cislady i can confirm this as true  incidental homosexuality   gay bi for women
#   us military and nato are fighting talibans too
# check out my lava lamp dude
# world war ii book lightning joe an autobiography by general j  lawton collins
# rainstorm downtown gloucester
#  gloucester  capeann  seagulls  triciaoneill  triciaoneillphoto
# i feel like if mkayla and cee ever got in the same room everyone should evacuate because it would be so petty and childish i couldnt deal
# a pyrotechnic artwork by cai guo qiang explodes into a blossom on the steps of the philadelphia
# damn that sinkhole on sunset
# i know its a question of interpretation but this is a sign of the apocalypse   i called it
#   someone has to be at the bottom of every league  tonight clearly demonstrated why the lions are where they are   sunk
# 4 equipment ego break upon dig your family internet hoke excepting versus a sinking term  dfljev
# offers
# in the words of charlie daniels fire on the mountain run boys run
# i liked a   video
# wreck with road blockage woodward avenue northbound at davison in m s   shoalstraffic
# u s national park services tonto national forest  stop the annihilation of the salt river wild horse
#   hi david in 2003 i saw the usa walk into a war that destroyed the lives of millions  you can prevent a repeat   irandeal
# it looks like a mudslide  and  gbbo is back with a belter
# well so much for outdoor postering    mothernature  hailstorm  rain  yycfringe  killhard
# ill be at sfa very soon pandemonium
#     i love 96 gal deco to death even if its a bit trickier to be great with  glad more weapons are getting splash wall
# byproduct of metal price meltdown is a higher silver price
#  biztip we recommend all businesses to get an alternative source of electricity   solar wind and batteries  have an emergency plan  now
# destruction magics fine just dont go burning down any buildings
# buildings are on fire and they have time for a business meeting  thestrain
#   listen to hurricane
# good way to end the day  geyser plus dust storm
# love living on my own  i can blaze inside my apt or on the balcony
# now thats what you call a batting collapse  theashes
# the seven seas   wreck of the giannis d  sunk after hitting a submerged reef in the
# if im also not mistaken were sitting right next 2 a nuclear reactor  not smart when we have a cataclysmic event  amp  that reator melts down
# its a miracle that mankind survived 70 years since one of the worst days in its history  all bets are off if it will survive the next 70
# some people are really natural disaster too
# must get hot in burning buildings
#
#  loses followers
# alaskas prince of wales  archipelagowolves are nearing  extinction  demand emergency protection   standforwolves
#   the hail is ruining everything  plus my car i havent even gotten yet  have yet another killer migraine and i lost my glasses
# until my death ill forever rep the jets
# it scares me that theres new versions of nuclear attack warnings like just knowing that governments still prepare for them
#   you dont know because you dont smoke  the way to make taxis and buses come is to light a cigarette to smoke while you wait
# tianta  breaking news  unconfirmed  i just heard a loud bang nearby  in what appears to be a blast of wind from my neighbours ass
# smelling a bon fire while driving makes me wanna be sitting near one making smores
#     i hate white people mo
#   middle of winter in sydney we have had snow bush fires and 78 degree days in the last week   keeps you on your toes for sure
# rt patrickjbutler  excellent damiengayle eyewitness account of kids company closure  you drop the bomb and expect
#   like a beautiful ass tragedy lol
#   then have the biggest nuclear disaster to ever have happened
# sadly the tent fly did not survive this hailstorm and now i have tears in the roof and water in the tent   only
#   haha so would you say its so hot your balls are burning off
# does anyone know why  murfreesboro  walmart was evacuated this evening
#  hot  funtenna  hijacking computers to send data as sound waves [black hat 2015]
# hellfire is surrounded by desires so be careful and dont let your desires control you   afterlife
# hollywood movie about trapped miners released in chile  the 33 hollywood movie about trapped miners starring
#      just between gray and ophelia red flames blazing around her person setting nearly everything in the area
# kirsten gillibrand
# ready to get annihilated for the bucs game
#   koreans are performing hijacking of the tokyo olympic games
#    runs at her for setting my forest on fire and bites the shit out of her neck
# real magic in real life
#
# women went missing in ohio town the focus of fbi probe after strange deaths and
#   california is in a drought  what are you gonna do about this issue  if you want to be president this attitude wont work with m
# heat wave is relentless   91f feels like 100 humidity 55
# relentless drought too  now dominicana  i know is worse in other places
#     not to mention a major contributor to the annihilation of israel
# mmmmmm im burning  im burning buildings im building  oooooohhhh oooh ooh
# i will adamantly opposed to nuclear weapons
#   desert storm was an unqualified victory a treaty was signed   under clinton the situation only got worse and more violent   tcot
# escaping her captors was the 1st step  now she must survive a deadly storm  amp  a wild looking recluse
# betrayed
#  books
#     people annihilated by last nights weather  really philip thought you would have forecast that
# could billboards hot 100 chart be displaced by these social media driven music charts
# nothing like a good fire
# reminder  mass murderer and white supremacist anders breivik was also unsurprisingly an anti feminist
#
# worried about how the ca drought might affect you  extreme weather  does it dampen our economy
# still rioting in a couple of hours left until i have to be up for class
# great michigan technique camp
# b1g thanks to
#
#  goblue  wrestleon
#   lava blast dan power red  pantherattack
# omg nixon lives  that is richard m  nixon tricky dicky right there in the picture isnt it  hiding in calgary he
# ee recalls power bar battery packs after explosion in students bedroom
#   lava blast dan power red  pantherattack
#         selmo u not catching flames from me  im just gonna be witnessing the slaughter
# a better look at what this catastrophic rain and flooding has done to our
# it looks like a mudslide poor thing     greatbritishbakeoff
# u s national park services tonto national forest  stop the annihilation of the salt river wild horse
# rare insight into  terror and how to fight it
# i see a massacre
#  360wisenews   chinas stock market crash  are there gems in the rubble
# pizza and beer in a tornado in austin  windy af right now
# storm in ri worse than last hurricane  my city amp 3others hardest hit  my yard looks like it was bombed  around 20000k still without power
# burned 129 calories doing 24 minutes of walking 3 5 mph brisk pace  myfitnesspal
#   you get me sis  this planet could do with a huge dose of obliteration
#    hes already done it by negotiating with the  1 state of terrorism in the world  what was his hurry in trying to get a deal
# hellfire  we dont even want to think about it or mention it so lets not do anything that leads to it  islam
# my baby girls car wreak this afternoon thank god no serious injuries and she was wearing her seatbelt
#   breaking news tonight kids were rescued from play room after a week with no food or water do to parents sex life haha
# this week first responders and dart members are participating in a four day intensive technical large animal
# ok peace i hope i fall off a cliff along with my dignity
# 2pcs 18w cree led work light  offroad lamp car truck boat mining 4wd flood beam   full rea
# we have overrun a natural disaster survival server
#   as you can imagine were inundated with requests each week for samples  amp  as much as wed love to be able to send sweets 1 2
#   lol natural disaster hospital crisis something is needed to get rid of some cast members
# a new tropical cyclone is forming near guam
#
# once it is formed it will be called molave
# i was peacefully sitting in my room and i heard this loud bang of something falling
# i just wanted to watch paper towns but the buildings on fire
# for these californians its like living in africas sahel desert   just finding water a daily chore
# stop the annihilation of the salt river wild horses
# sevenfigz has a crush
#     hello 911 yeah we have someone drowning here send a medic
# someone  mentions gansey on fire
# me busting through the brick walls of seven different buildings
#  books a flight to burma when country is enduring political unrest and a natural disaster  no wonder it was so cheap ay
# zeal is a volcano the peak of which the grass of indecisiveness does not grow
#
#   did you see  hurricane  guillermo with  meteoearth
# back on the beach after the deluge   surf camp in motion   our surf therapy programme kicked off today for
#       whether pressure or not non wud not survived even if thalapathi didnt release
# i hope this tsunami clears b4 i have to walk outside to my car
#  gunsense answer to  gfzs  break law on the minuscule chance a mass murderer shows up
# ancient mayan tablet found in jungle temple
# hollywood movie about trapped miners released in chile
# hurricane 30stm quem lembra
# good thing there was actually just a legit fire in the mall and nobody evacuated
#   so glad i saved them all at once then didnt want you stealing my thunder  p
# omfg
# didnt expect drag me down to be the first song pandora played
#
# omfg i screamed so loud
# my coworker is scared
#       usually id agree  once the whole chopping heads off throwing gays off rooftops  amp  suicide bombing start
# not only does he know the latest research the kiddos gi specialist sang the volcano number from inside out  now that is whole person care
#    prez  mr  president you are the biggest terrorist and trouble maker in the world  you create terrorist you sponsor terrorist
#  sink holes earth slides and avalanches gt gt allah  islam  sinkhole  landslide  avalanche  usa  france  uk  usgs  emsc
# sustainability task force presents levy to fund emergency services   wdtv
#   its like theres fire in my skin and im drowning from within
#
# only you can prevent forest fires
# the thunder shook my house woke my sister and made car alarms go off
# im on top of the hill and i can see a fire in the woods
# a big issue left undone is how to get home if adverse weather hits    has no real emergency plan in place
# win  lisowski whitewashes the whirlwind 5 0 in round 2 of shanghai masters quals
# body shops inundated with cars dented by hail  good news insurance pays  bad news    you are stuck with deductible
#  wcvb
# if youre in search of powerful content to improve your business or have been frustrated with the deluge of quantit
# i just added sandy first responders lost their homes to vip home page group on
#
# were  hiring  click to apply  rn ii emergency services ft 7p 7a
#     im actually currently dressed for a snowstorm despite being in the middle of a texas summer  thanks office a c
#     crazy to use the netanyahu argument iran can flush a nuclear reactor down the toilet
#  looks outside at the windstorm  niiiice
# came across this fire video not mine enjoy fire  firemen  firetruck  emergency  rescue  911  summertime  sirens
# so much shit has happened today wtf idk how i survive thruuu it all
# julian knight     dismisses mass murderers attempt to increase prisoner pay  challenged quantum of 5  increase 2013
# my hand is burning
#
#   you up to commiting mass murder tonight
# new post from
# why werent they taken back to africa once rescued   c4news
#  nowplaying  dubstep hardstyle trap messy mix (event recording) by alien casualty on
#   by ur  logic if bridge didnt collapse then second train engine should cross bridge then
#    everyone here  ahh i hate snow
#
# me  lol u call this a snowstorm
#
#  growingupincolorado
# (sj gist)  148 houses farm produce destroy
# i liked a   video
# keeps askin me what this means
# not like i got the answers
# plus if i say the wrong thing
# this might just turn into a disaster
# the sunset looked like an erupting volcano   my initial thought was the pixar short lava
# leeds fan  rioting in embra at a lower tier  league cup final   dee dum
# wipp emergency activated because of slightly elevated levels of radiation   sejorg
#   its a well known fact that the st valentines day massacre could have been avoided with some oompah period tom waits
# you picture buildings burning to the ground from the basement to the streetlight
#
# im not your drinking problem
# a hole is in the sky
# i came to kill indians for fun  video of smirking and remorseless pakistani killer shows him boasting
#   dont be a fart  in a windstorm follow me already  jeez
#   mini heat wave apaz
# lets not forget our wounded female veterans
# interview on the collapse of materialism best  talkradio listen live
# how many trains derailed that   has to shut down orange blue in most of dc  the avengers made less of a mess
# is he about to crash
# did the queen die
# did something explode
# who knows
# deliver value  a cash source crash course
# okay not sure the word mass murder applies during this war but it was horrendous none the less
# the sunset boys wreck my bed   original 1979 usa gimp label  vinyl 7 45  newave
# pandemonium use to be my fav cd   i had to get it
